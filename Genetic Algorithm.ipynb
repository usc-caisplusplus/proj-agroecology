# %% [markdown]
# # Environment Code

# %%
import numpy as np
import matplotlib.pyplot as plt
import gym
from gym import error, spaces, utils
from gym.utils import seeding
from enum import Enum

class Plant:
    def __init__(self, species, maturity=90):
        self.species = species
        self.maturity = maturity         # consider 'days_to_maturity'
        self.age = 0
        
    def __repr__(self):
        return "{}".format(self.species)
    

class Field(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, size=5, sow_limit=200, season=120, calendar=0):
        # parameters for overall field character
        self.size = size
        self.sow_limit = sow_limit
        self.season = season
        self.calendar = calendar
        
        # constants for computing end-of-season reward---distances represent meters
        self.crowding_dist = .02
        self.maize_maize_dist = .1
        self.bean_support_dist = .1
        self.crowding_penalty = .1
        self.maize_maize_penalty = .9
        self.bean_support_bonus = .6
        
        # OpenAI action and observation space specifications
        self.action_space = spaces.Discrete(4)
        ### self.observation_space = spaces.???
        
        # field is initialized by calling reset()
        self.field = None
        
    def step(self, action):
        # sow plants (or wait) depending on actions chosen
        # action is an array of n choices; value of n specified in agent code sow_limit
        # could be cleaned up with plants as an enumeration?

        ###Experiment: each choice should be represented as an array with 3 elements:
        ### plant choice, y coordinate, x coordinate (in that order).
        ### i.e. action should look like: [[choice1, y1, x1], [choice2, y2, x2]...]
               
        for choice in action:
            if choice[0] == 0:
                self.field = np.append(self.field, [[self.size * choice[1], 
                                                 self.size * choice[2], 
                                                 Plant('Maize')]], axis=0)
            elif choice[0] == 1:
                self.field = np.append(self.field, [[self.size * choice[1], 
                                                 self.size * choice[2], 
                                                 Plant('Bean')]], axis=0)
            elif choice[0] == 2:
                self.field = np.append(self.field, [[self.size * choice[1], 
                                                 self.size * choice[2], 
                                                 Plant('Squash')]], axis=0)
            # when choice == 3, nothing is done (agent waits)   
        
        # increment timekeeping
        self.calendar +=1
        for plant in self.field:
            plant[2].age += 1

        done = self.calendar == self.season
            
        if not done:
            reward = 0
        else:
            reward = self.get_reward()
            
        return self.field, reward, done, self.action_history
    
    def reset(self):
        # field is initialized with one random corn plant in order to make sowing (by np.append) work
        self.field = np.array([[self.size * np.random.random(), 
                                self.size * np.random.random(), 
                                Plant('Maize')]])
        # timekeeping is reset
        self.calendar = 0
        #### MODIFICATION ####
        ## Enables GA Agent to begin interaction ## 
        return self.field
        
    def render(self, mode='human'):
        # initialize plant type arrays so that pyplot won't break if any is empty
        maize = np.array([[None, None]])
        bean = np.array([[None, None]])
        squash = np.array([[None, None]])
        maize_imm = np.array([[None, None]])
        bean_imm = np.array([[None, None]])
        squash_imm = np.array([[None, None]])
        maize_r = 0
        bean_r = 0
        squash_r = 0
        maize_imm_r = 0
        bean_imm_r = 0
        squash_imm_r = 0
        
        # replace initial arrays with coordinates for each plant type; imm are plants that haven't matured
        maize = np.array([row for row in self.field 
                             if row[2].__repr__() == 'Maize' and row[2].age >= row[2].maturity])
        
        for plant in maize:
          maize_r += 1
        bean = np.array([row for row in self.field 
                            if row[2].__repr__() == 'Bean' and row[2].age >= row[2].maturity])
        
        for plant in bean:
          bean_r += 1

        squash = np.array([row for row in self.field 
                              if row[2].__repr__() == 'Squash' and row[2].age >= row[2].maturity])
        
        for plant in squash:
          squash_r += 1
        maize_imm = np.array([row for row in self.field 
                             if row[2].__repr__() == 'Maize' and row[2].age < row[2].maturity])
        
        for plant in maize_imm:
          maize_imm_r += 1

        bean_imm = np.array([row for row in self.field 
                             if row[2].__repr__() == 'Bean' and row[2].age < row[2].maturity])
        
        for plant in bean_imm:
          bean_imm_r += 1

        squash_imm = np.array([row for row in self.field 
                             if row[2].__repr__() == 'Squash' and row[2].age < row[2].maturity])
        
        for plant in squash_imm:
          squash_imm_r += 1
        
        # plot the field
        plt.figure(figsize=(10, 10))
        if not(maize_r == 0):
          plt.scatter(maize[:,0], maize[:,1], c='green', s=200, marker = 'o', alpha=.5, edgecolor='#303030')
        if not(bean_r == 0):
          plt.scatter(bean[:,0], bean[:,1], c='brown', s=150, marker = 'o', alpha=.5, edgecolor='#303030')
        if not(squash_r == 0):
          plt.scatter(squash[:,0], squash[:,1], c='orange', s=400, marker = 'o', alpha=.5, edgecolor='#303030')
        if not(maize_imm_r == 0):
          plt.scatter(maize_imm[:,0], maize_imm[:,1], c='green', s=200, marker = 'o', alpha=.1, edgecolor='#303030')
        if not(bean_imm_r == 0):
          plt.scatter(bean_imm[:,0], bean_imm[:,1], c='brown', s=200, marker = 'o', alpha=.1, edgecolor='#303030')
        if not(squash_imm_r == 0):
          plt.scatter(squash_imm[:,0], squash_imm[:,1], c='orange', s=200, marker = 'o', alpha=.1, edgecolor='#303030')

        plt.show()
        
        print("Total yield in Calories is {}.\n---\n".format(round(reward, 1)))
    
    def close(self):
        # unneeded right now? AFAICT this is only used to shut down realtime movie visualizations
        pass
    
    def get_reward(self):
        # array of plant coordinates for computing distances
        xy_array = np.array([[row[0], row[1]] for row in self.field])

        # distances[m,n] is distance from mth to nth plant in field
        distances = np.linalg.norm(xy_array - xy_array[:,None], axis=-1)
        
        reward = 0
        i = 0
        while i < len(self.field):
            if self.field[i,2].age < self.field[i,2].maturity:
                reward += 0
            elif self.field[i,2].__repr__() == 'Maize':
                cal = 1
                j = 0
                while j < len(distances[0]):
                    if (self.field[j,2].__repr__() == 'Bean' 
                            and distances[i,j] < self.bean_support_dist):
                        cal += self.bean_support_bonus
                    if (self.field[j,2].__repr__() == 'Maize' 
                            and i !=j 
                            and distances[i,j] < self.maize_maize_dist):
                        cal *= self.maize_maize_penalty
                    if 0 <= distances[i,j] < self.crowding_dist:
                        cal *= self.crowding_penalty
                    j += 1
                reward += cal
            elif self.field[i,2].__repr__() == 'Bean':
                reward += .25
            elif self.field[i,2].__repr__() == 'Squash':
                reward += 3
            i += 1        
        return reward

# %% [markdown]
# # NEAT Code

# %%
# !pip install neat-python
from google.colab import drive
drive.mount('/content/drive')

# %%
## Provided visualization code (by NEAT) ##

import copy
import warnings

import graphviz
import matplotlib.pyplot as plt
import numpy as np


def plot_stats(statistics, ylog=False, view=False, filename='avg_fitness.svg'):
    """ Plots the population's average and best fitness. """
    if plt is None:
        warnings.warn("This display is not available due to a missing optional dependency (matplotlib)")
        return

    generation = range(len(statistics.most_fit_genomes))
    best_fitness = [c.fitness for c in statistics.most_fit_genomes]
    avg_fitness = np.array(statistics.get_fitness_mean())
    stdev_fitness = np.array(statistics.get_fitness_stdev())

    plt.plot(generation, avg_fitness, 'b-', label="average")
    #plt.plot(generation, avg_fitness - stdev_fitness, 'g-.', label="-1 sd")
    plt.plot(generation, avg_fitness + stdev_fitness, 'g-.', label="+1 sd")
    plt.plot(generation, best_fitness, 'r-', label="best")

    plt.title("Population's average and best fitness")
    plt.xlabel("Generations")
    plt.ylabel("Fitness")
    plt.grid()
    plt.legend(loc="best")
    if ylog:
        plt.gca().set_yscale('symlog')

    plt.savefig(filename)
    if view:
        plt.show()

    plt.close()


def plot_spikes(spikes, view=False, filename=None, title=None):
    """ Plots the trains for a single spiking neuron. """
    if plt is None:
        warnings.warn("This display is not available due to a missing optional dependency (matplotlib)")
        return

    t_values = [t for t, I, v, u in spikes]
    v_values = [v for t, I, v, u in spikes]
    u_values = [u for t, I, v, u in spikes]
    I_values = [I for t, I, v, u in spikes]

    fig = plt.figure()
    plt.subplot(3, 1, 1)
    plt.ylabel("Potential (mv)")
    plt.xlabel("Time (in ms)")
    plt.grid()
    plt.plot(t_values, v_values, "g-")

    if title is None:
        plt.title("Izhikevich's spiking neuron model")
    else:
        plt.title("Izhikevich's spiking neuron model ({0!s})".format(title))

    plt.subplot(3, 1, 2)
    plt.ylabel("Recovery (u)")
    plt.xlabel("Time (in ms)")
    plt.grid()
    plt.plot(t_values, u_values, "r-")

    plt.subplot(3, 1, 3)
    plt.ylabel("Current (I)")
    plt.xlabel("Time (in ms)")
    plt.grid()
    plt.plot(t_values, I_values, "r-o")

    if filename is not None:
        plt.savefig(filename)

    if view:
        plt.show()
        plt.close()
        fig = None

    return fig


def plot_species(statistics, view=False, filename='speciation.svg'):
    """ Visualizes speciation throughout evolution. """
    if plt is None:
        warnings.warn("This display is not available due to a missing optional dependency (matplotlib)")
        return

    species_sizes = statistics.get_species_sizes()
    num_generations = len(species_sizes)
    curves = np.array(species_sizes).T

    fig, ax = plt.subplots()
    ax.stackplot(range(num_generations), *curves)

    plt.title("Speciation")
    plt.ylabel("Size per Species")
    plt.xlabel("Generations")

    plt.savefig(filename)

    if view:
        plt.show()

    plt.close()


def draw_net(config, genome, view=False, filename=None, node_names=None, show_disabled=True, prune_unused=False,
             node_colors=None, fmt='svg'):
    """ Receives a genome and draws a neural network with arbitrary topology. """
    # Attributes for network nodes.
    if graphviz is None:
        warnings.warn("This display is not available due to a missing optional dependency (graphviz)")
        return

    if node_names is None:
        node_names = {}

    assert type(node_names) is dict

    if node_colors is None:
        node_colors = {}

    assert type(node_colors) is dict

    node_attrs = {
        'shape': 'circle',
        'fontsize': '9',
        'height': '0.2',
        'width': '0.2'}

    dot = graphviz.Digraph(format=fmt, node_attr=node_attrs)

    inputs = set()
    for k in config.genome_config.input_keys:
        inputs.add(k)
        name = node_names.get(k, str(k))
        input_attrs = {'style': 'filled', 'shape': 'box', 'fillcolor': node_colors.get(k, 'lightgray')}
        dot.node(name, _attributes=input_attrs)

    outputs = set()
    for k in config.genome_config.output_keys:
        outputs.add(k)
        name = node_names.get(k, str(k))
        node_attrs = {'style': 'filled', 'fillcolor': node_colors.get(k, 'lightblue')}

        dot.node(name, _attributes=node_attrs)

    if prune_unused:
        connections = set()
        for cg in genome.connections.values():
            if cg.enabled or show_disabled:
                connections.add(cg.key)

        used_nodes = copy.copy(outputs)
        pending = copy.copy(outputs)
        while pending:
            new_pending = set()
            for a, b in connections:
                if b in pending and a not in used_nodes:
                    new_pending.add(a)
                    used_nodes.add(a)
            pending = new_pending
    else:
        used_nodes = set(genome.nodes.keys())

    for n in used_nodes:
        if n in inputs or n in outputs:
            continue

        attrs = {'style': 'filled', 'fillcolor': node_colors.get(n, 'white')}
        dot.node(str(n), _attributes=attrs)

    for cg in genome.connections.values():
        if cg.enabled or show_disabled:
            #if cg.input not in used_nodes or cg.output not in used_nodes:
            #    continue
            input, output = cg.key
            a = node_names.get(input, str(input))
            b = node_names.get(output, str(output))
            style = 'solid' if cg.enabled else 'dotted'
            color = 'green' if cg.weight > 0 else 'red'
            width = str(0.1 + abs(cg.weight / 5.0))
            dot.edge(a, b, _attributes={'style': style, 'color': color, 'penwidth': width})

    dot.render(filename, view=view)

    return dot

# %%
def field_to_inputs(field, history):
  maize_r = 0
  bean_r = 0
  squash_r = 0
  maize_imm_r = 0
  bean_imm_r = 0
  squash_imm_r = 0

  # replace initial arrays with coordinates for each plant type; imm are plants that haven't matured
  maize = np.array([row for row in field 
                        if row[2].__repr__() == 'Maize' and row[2].age >= row[2].maturity])

  for plant in maize:
    maize_r += 1

  bean = np.array([row for row in field 
                      if row[2].__repr__() == 'Bean' and row[2].age >= row[2].maturity])

  for plant in bean:
    bean_r += 1

  squash = np.array([row for row in field 
                        if row[2].__repr__() == 'Squash' and row[2].age >= row[2].maturity])

  for plant in squash:
    squash_r += 1

  maize_imm = np.array([row for row in field 
                        if row[2].__repr__() == 'Maize' and row[2].age < row[2].maturity])

  for plant in maize_imm:
    maize_imm_r += 1

  bean_imm = np.array([row for row in field 
                        if row[2].__repr__() == 'Bean' and row[2].age < row[2].maturity])

  for plant in bean_imm:
    bean_imm_r += 1

  squash_imm = np.array([row for row in field 
                        if row[2].__repr__() == 'Squash' and row[2].age < row[2].maturity])

  for plant in squash_imm:
    squash_imm_r += 1

  data_list = [maize_r, bean_r, squash_r, maize_imm_r, bean_imm_r, squash_imm_r]

  for action in history:
    for num in action:
      data_list.append(num)
  while not(len(data_list) == 27):
    data_list.append(-1)
  return data_list

# %%
import matplotlib as mpl

def exp_reward(field):
  # initialize plant type arrays so that pyplot won't break if any is empty
  maize = np.array([[None, None]])
  bean = np.array([[None, None]])
  squash = np.array([[None, None]])
  maize_imm = np.array([[None, None]])
  bean_imm = np.array([[None, None]])
  squash_imm = np.array([[None, None]])
  maize_r = 0
  bean_r = 0
  squash_r = 0
  maize_imm_r = 0
  bean_imm_r = 0
  squash_imm_r = 0
  
  # replace initial arrays with coordinates for each plant type; imm are plants that haven't matured
  maize = np.array([row for row in field 
                        if row[2].__repr__() == 'Maize' and row[2].age >= row[2].maturity])
  
  for plant in maize:
    maize_r += 1
  bean = np.array([row for row in field 
                      if row[2].__repr__() == 'Bean' and row[2].age >= row[2].maturity])
  
  for plant in bean:
    bean_r += 1

  squash = np.array([row for row in field 
                        if row[2].__repr__() == 'Squash' and row[2].age >= row[2].maturity])
  
  for plant in squash:
    squash_r += 1
  maize_imm = np.array([row for row in field 
                        if row[2].__repr__() == 'Maize' and row[2].age < row[2].maturity])
  
  for plant in maize_imm:
    maize_imm_r += 1

  bean_imm = np.array([row for row in field 
                        if row[2].__repr__() == 'Bean' and row[2].age < row[2].maturity])
  
  for plant in bean_imm:
    bean_imm_r += 1

  squash_imm = np.array([row for row in field 
                        if row[2].__repr__() == 'Squash' and row[2].age < row[2].maturity])
  
  for plant in squash_imm:
    squash_imm_r += 1
  
  # plot the field
  fig = plt.figure(figsize=(0.2, 0.2))
  if not(maize_r == 0):
    plt.scatter(maize[:,0], maize[:,1], c='black', s=8, marker = 'o', alpha=.8)
  if not(bean_r == 0):
    plt.scatter(bean[:,0], bean[:,1], c='black', s=4, marker = 'o', alpha=.7)
  if not(squash_r == 0):
    plt.scatter(squash[:,0], squash[:,1], c='black', s=6, marker = 'o', alpha=.6)
  if not(maize_imm_r == 0):
    plt.scatter(maize_imm[:,0], maize_imm[:,1], c='black', s=7, marker = 'o', alpha=.3)
  if not(bean_imm_r == 0):
    plt.scatter(bean_imm[:,0], bean_imm[:,1], c='black', s=3, marker = 'o', alpha=.2)
  if not(squash_imm_r == 0):
    plt.scatter(squash_imm[:,0], squash_imm[:,1], c='black', s=5, marker = 'o', alpha=.1)

  mpl.use('agg')
  fig.canvas.draw()
  img = np.array(fig.canvas.buffer_rgba())
  img = np.rint(img[...,:3] @ [0.2126, 0.7152, 0.0722]).astype(np.uint8)
  plt.close()

  return img.ravel()

# %%
## TODO: Consider maturity in this ## 
def field_append(field, choice, size):
  if choice[0] == 0:
      field = np.append(field, [[size * choice[1], 
                                        size * choice[2], 
                                        Plant('Maize')]], axis=0)
  elif choice[0] == 1:
      field = np.append(field, [[size * choice[1], 
                                        size * choice[2], 
                                        Plant('Bean')]], axis=0)
  elif choice[0] == 2:
      field = np.append(field, [[size * choice[1], 
                                      size * choice[2], 
                                        Plant('Squash')]], axis=0)
      
  return field

# %%
import multiprocessing
import os
import pickle

import neat


runs_per_net = 2


# Use the NN network phenotype and the discrete actuator force function.
def eval_genome(genome, config):
  net = neat.nn.FeedForwardNetwork.create(genome, config)

  fitnesses = []

  for runs in range(runs_per_net):
    env = Field()

    fitness = 0.0
    field_state = env.reset()
    network_input = exp_reward(field_state)
    done = False
    while not done:
      all_acts = []
      for i in range(5):
        action = net.activate(network_input)
        
        #vals in action are in range [-1,1]
        #scale them to [0,1]
        for i in range(len(action)):
          action[i] = (action[i] + 1)/2.0
        #scale from [0,1] to {0,1,2,3}
        action[0] = ((action[0]) * 15) // 4
        all_acts.append(action)
        field_state = field_append(field_state, action, 5)
        network_input = exp_reward(field_state)

      field_state, reward, done, history = env.step(all_acts) 
      network_inputs = exp_reward(field_state)
      fitness += reward
        
    fitnesses.append(fitness)

  # The genome's fitness is its worst performance across all runs.
  return min(fitnesses)


def eval_genomes(genomes, config):
    for genome_id, genome in genomes:
        genome.fitness = eval_genome(genome, config)


def run():
    # Load the config file, which is assumed to live in
    # the same directory as this script.
    config_path = '/content/drive/My Drive/agroecology/Config'
    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_path)

    pop = neat.Population(config)
    stats = neat.StatisticsReporter()
    pop.add_reporter(stats)
    pop.add_reporter(neat.StdOutReporter(True))

    pe = neat.ParallelEvaluator(multiprocessing.cpu_count(), eval_genome)
    winner = pop.run(pe.evaluate, 1)

    # Save the winner.
    with open('winner-feedforward', 'wb') as f:
        pickle.dump(winner, f)

    print(winner)

    plot_stats(stats, ylog=True, view=True, filename="feedforward-fitness.svg")
    plot_species(stats, view=True, filename="feedforward-speciation.svg")

    node_names = {-1: 'x', -2: 'dx', -3: 'theta', -4: 'dtheta', 0: 'control'}
    draw_net(config, winner, True, node_names=node_names)

    draw_net(config, winner, view=True, node_names=node_names,
                       filename="winner-feedforward.gv")
    draw_net(config, winner, view=True, node_names=node_names,
                       filename="winner-feedforward-enabled.gv", show_disabled=False)
    draw_net(config, winner, view=True, node_names=node_names,
                       filename="winner-feedforward-enabled-pruned.gv", show_disabled=False, prune_unused=True)


if __name__ == '__main__':
    run()

# %%
with open('winner-feedforward', 'rb') as f:
  c = pickle.load(f)
print("Loaded genome:")
print(c)


config_path = '/content/drive/My Drive/agroecology/Config'
config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_path)

net = neat.nn.FeedForwardNetwork.create(c, config)

env = Field()

fitness = 0.0
observation = field_to_inputs(env.reset(), [])
done = False
while not done:
      action = net.activate(observation)
      for i in range(len(action)):
        action[i] = (action[i] + 1)/2.0
      for i in range(5):
        action[3*i] = (action[3*i] * 15) // 4
      action = np.reshape(action, (5,3))
      print(action)

      observation, reward, done, history = env.step(action) 
      if not done:
        observation = field_to_inputs(observation, history)
      fitness += reward
print("FITNESS:" ,fitness)

print(np.ravel(observation).shape)
print(field_to_inputs(observation, history))
env.render()
test = exp_reward(observation))
# Out:
# Loaded genome:
# Key: 820
# Fitness: 62.02838442520749
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=0.37245992777995385, response=1.0, activation=clamped, aggregation=sum)
# 	1 DefaultNodeGene(key=1, bias=0.9115405616536123, response=1.0, activation=clamped, aggregation=sum)
# 	2 DefaultNodeGene(key=2, bias=-2.49335295978791, response=1.0, activation=clamped, aggregation=sum)
# 	3 DefaultNodeGene(key=3, bias=-0.4075578647794684, response=1.0, activation=clamped, aggregation=sum)
# 	4 DefaultNodeGene(key=4, bias=2.339191191377314, response=1.0, activation=clamped, aggregation=sum)
# 	5 DefaultNodeGene(key=5, bias=0.5237179263388028, response=1.0, activation=clamped, aggregation=sum)
# 	6 DefaultNodeGene(key=6, bias=1.3645913691509772, response=1.0, activation=clamped, aggregation=sum)
# 	7 DefaultNodeGene(key=7, bias=-2.1107503978716915, response=1.0, activation=clamped, aggregation=sum)
# 	8 DefaultNodeGene(key=8, bias=0.37474740626861985, response=1.0, activation=clamped, aggregation=sum)
# 	9 DefaultNodeGene(key=9, bias=-0.4224192208831199, response=1.0, activation=clamped, aggregation=sum)
# 	10 DefaultNodeGene(key=10, bias=-2.3482735466362947, response=1.0, activation=clamped, aggregation=sum)
# 	11 DefaultNodeGene(key=11, bias=1.1640191922558494, response=1.0, activation=clamped, aggregation=sum)
# 	12 DefaultNodeGene(key=12, bias=-1.5235362652344313, response=1.0, activation=clamped, aggregation=sum)
# 	13 DefaultNodeGene(key=13, bias=-1.0388240334248546, response=1.0, activation=clamped, aggregation=sum)
# 	14 DefaultNodeGene(key=14, bias=-0.32248573987245566, response=1.0, activation=clamped, aggregation=sum)
# 	255 DefaultNodeGene(key=255, bias=0.3470131616585953, response=1.0, activation=clamped, aggregation=sum)
# 	256 DefaultNodeGene(key=256, bias=-1.8601118318714596, response=1.0, activation=clamped, aggregation=sum)
# 	258 DefaultNodeGene(key=258, bias=0.9528042384780852, response=1.0, activation=clamped, aggregation=sum)
# 	259 DefaultNodeGene(key=259, bias=0.9722513113648608, response=1.0, activation=clamped, aggregation=sum)
# 	261 DefaultNodeGene(key=261, bias=0.6343814463616593, response=1.0, activation=clamped, aggregation=sum)
# 	262 DefaultNodeGene(key=262, bias=-1.6895987156264258, response=1.0, activation=clamped, aggregation=sum)
# 	469 DefaultNodeGene(key=469, bias=0.3303788592287329, response=1.0, activation=clamped, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-27, 1), weight=0.3749080101815866, enabled=True)
# 	DefaultConnectionGene(key=(-27, 2), weight=-3.0066472624230816, enabled=True)
# 	DefaultConnectionGene(key=(-27, 3), weight=0.08287045097339074, enabled=True)
# 	DefaultConnectionGene(key=(-27, 5), weight=1.9450646955832338, enabled=True)
# 	DefaultConnectionGene(key=(-27, 7), weight=2.3690181200425338, enabled=True)
# 	DefaultConnectionGene(key=(-27, 8), weight=0.3821885230580352, enabled=True)
# 	DefaultConnectionGene(key=(-27, 9), weight=-0.3587884656923017, enabled=False)
# 	DefaultConnectionGene(key=(-27, 10), weight=0.12753123777133063, enabled=True)
# 	DefaultConnectionGene(key=(-27, 11), weight=-0.7833628726513078, enabled=True)
# 	DefaultConnectionGene(key=(-27, 14), weight=1.1740736418809874, enabled=True)
# 	DefaultConnectionGene(key=(-27, 255), weight=0.572294676283307, enabled=True)
# 	DefaultConnectionGene(key=(-27, 256), weight=-1.9313677824086621, enabled=True)
# 	DefaultConnectionGene(key=(-27, 258), weight=1.1649843775878492, enabled=True)
# 	DefaultConnectionGene(key=(-27, 259), weight=0.7576539445456079, enabled=True)
# 	DefaultConnectionGene(key=(-27, 261), weight=-0.5554470919877843, enabled=True)
# 	DefaultConnectionGene(key=(-27, 262), weight=-0.5807499399467212, enabled=True)
# 	DefaultConnectionGene(key=(-26, 3), weight=-0.7915385482402855, enabled=True)
# 	DefaultConnectionGene(key=(-26, 4), weight=-0.4319272424685598, enabled=True)
# 	DefaultConnectionGene(key=(-26, 6), weight=-0.8498830187711119, enabled=True)
# 	DefaultConnectionGene(key=(-26, 7), weight=1.3679567225312643, enabled=True)
# 	DefaultConnectionGene(key=(-26, 8), weight=0.6933004543209631, enabled=True)
# 	DefaultConnectionGene(key=(-26, 11), weight=-0.6221338558542426, enabled=True)
# 	DefaultConnectionGene(key=(-26, 12), weight=-1.7329221313408674, enabled=True)
# 	DefaultConnectionGene(key=(-26, 13), weight=0.48641405070575416, enabled=True)
# 	DefaultConnectionGene(key=(-26, 255), weight=0.2879624778480151, enabled=True)
# 	DefaultConnectionGene(key=(-26, 259), weight=0.2612451260201062, enabled=True)
# 	DefaultConnectionGene(key=(-25, 4), weight=-1.0137904178191293, enabled=True)
# 	DefaultConnectionGene(key=(-25, 5), weight=0.9644171677526743, enabled=True)
# 	DefaultConnectionGene(key=(-25, 6), weight=0.7142262046623533, enabled=True)
# 	DefaultConnectionGene(key=(-25, 9), weight=-0.4883652128325666, enabled=True)
# 	DefaultConnectionGene(key=(-25, 10), weight=-0.24306684797011485, enabled=True)
# 	DefaultConnectionGene(key=(-25, 13), weight=0.41514890447450037, enabled=True)
# 	DefaultConnectionGene(key=(-25, 255), weight=3.495492254020362, enabled=False)
# 	DefaultConnectionGene(key=(-25, 256), weight=-0.31880847274439317, enabled=True)
# 	DefaultConnectionGene(key=(-25, 258), weight=-0.09601897592832453, enabled=True)
# 	DefaultConnectionGene(key=(-25, 261), weight=-1.5274541153963148, enabled=True)
# 	DefaultConnectionGene(key=(-25, 262), weight=-2.1243889472758846, enabled=True)
# 	DefaultConnectionGene(key=(-24, 0), weight=-0.8185309743239103, enabled=True)
# 	DefaultConnectionGene(key=(-24, 3), weight=-1.1093806796559942, enabled=True)
# 	DefaultConnectionGene(key=(-24, 4), weight=0.9793021498959383, enabled=True)
# 	DefaultConnectionGene(key=(-24, 5), weight=-1.0351075123244167, enabled=True)
# 	DefaultConnectionGene(key=(-24, 10), weight=-0.9001645159083052, enabled=False)
# 	DefaultConnectionGene(key=(-24, 12), weight=-2.5007366819502255, enabled=True)
# 	DefaultConnectionGene(key=(-24, 14), weight=1.095578231515989, enabled=True)
# 	DefaultConnectionGene(key=(-24, 256), weight=-0.5426989053272762, enabled=True)
# 	DefaultConnectionGene(key=(-24, 259), weight=-0.5557500767051841, enabled=True)
# 	DefaultConnectionGene(key=(-24, 261), weight=-0.04893204041168231, enabled=True)
# 	DefaultConnectionGene(key=(-24, 262), weight=-0.7586761284821155, enabled=True)
# 	DefaultConnectionGene(key=(-23, 1), weight=0.11350272379913712, enabled=True)
# 	DefaultConnectionGene(key=(-23, 2), weight=-1.7177606792447824, enabled=True)
# 	DefaultConnectionGene(key=(-23, 3), weight=1.0475007081949905, enabled=True)
# 	DefaultConnectionGene(key=(-23, 5), weight=-0.29684202339715055, enabled=True)
# 	DefaultConnectionGene(key=(-23, 6), weight=-0.09121847943012261, enabled=True)
# 	DefaultConnectionGene(key=(-23, 8), weight=-0.29351597559779286, enabled=True)
# 	DefaultConnectionGene(key=(-23, 9), weight=-0.1200204248544014, enabled=True)
# 	DefaultConnectionGene(key=(-23, 10), weight=0.6186840086344396, enabled=True)
# 	DefaultConnectionGene(key=(-23, 12), weight=-2.4020030727357486, enabled=True)
# 	DefaultConnectionGene(key=(-23, 255), weight=-1.1038811924882772, enabled=True)
# 	DefaultConnectionGene(key=(-23, 256), weight=-0.5394763818771094, enabled=True)
# 	DefaultConnectionGene(key=(-23, 258), weight=0.015353942382603875, enabled=True)
# 	DefaultConnectionGene(key=(-23, 259), weight=-1.1639892423814056, enabled=True)
# 	DefaultConnectionGene(key=(-23, 261), weight=0.3034929998064838, enabled=True)
# 	DefaultConnectionGene(key=(-23, 469), weight=0.24188841810741796, enabled=False)
# 	DefaultConnectionGene(key=(-22, 0), weight=-1.284040879902284, enabled=True)
# 	DefaultConnectionGene(key=(-22, 1), weight=-1.0884658615426757, enabled=False)
# 	DefaultConnectionGene(key=(-22, 3), weight=-1.5902779584943996, enabled=True)
# 	DefaultConnectionGene(key=(-22, 4), weight=-0.08473155208908793, enabled=True)
# 	DefaultConnectionGene(key=(-22, 5), weight=-3.0632874778662496, enabled=True)
# 	DefaultConnectionGene(key=(-22, 6), weight=2.559415295161138, enabled=True)
# 	DefaultConnectionGene(key=(-22, 8), weight=-0.6269029585899277, enabled=True)
# 	DefaultConnectionGene(key=(-22, 9), weight=0.306672535105167, enabled=True)
# 	DefaultConnectionGene(key=(-22, 12), weight=1.487723961158475, enabled=False)
# 	DefaultConnectionGene(key=(-22, 14), weight=-0.29852395561472156, enabled=True)
# 	DefaultConnectionGene(key=(-22, 256), weight=-0.013268227709435698, enabled=True)
# 	DefaultConnectionGene(key=(-21, 0), weight=-2.0863742970136725, enabled=True)
# 	DefaultConnectionGene(key=(-21, 1), weight=-0.17477334583340415, enabled=True)
# 	DefaultConnectionGene(key=(-21, 3), weight=0.24282854116839836, enabled=True)
# 	DefaultConnectionGene(key=(-21, 4), weight=-1.126566050436853, enabled=True)
# 	DefaultConnectionGene(key=(-21, 9), weight=0.08333464064977074, enabled=True)
# 	DefaultConnectionGene(key=(-21, 11), weight=0.35339013472643543, enabled=True)
# 	DefaultConnectionGene(key=(-21, 255), weight=1.125945192396747, enabled=True)
# 	DefaultConnectionGene(key=(-21, 256), weight=0.15440747499443647, enabled=True)
# 	DefaultConnectionGene(key=(-21, 261), weight=0.6267258606889078, enabled=True)
# 	DefaultConnectionGene(key=(-20, 0), weight=-0.45344351607939737, enabled=True)
# 	DefaultConnectionGene(key=(-20, 4), weight=0.4518475954368264, enabled=True)
# 	DefaultConnectionGene(key=(-20, 6), weight=2.2044315626777333, enabled=True)
# 	DefaultConnectionGene(key=(-20, 8), weight=1.3666791961755125, enabled=True)
# 	DefaultConnectionGene(key=(-20, 10), weight=0.7101714864988682, enabled=True)
# 	DefaultConnectionGene(key=(-20, 11), weight=1.638502398689178, enabled=True)
# 	DefaultConnectionGene(key=(-20, 255), weight=-5.105138657634536, enabled=True)
# 	DefaultConnectionGene(key=(-20, 256), weight=0.6849723494052896, enabled=True)
# 	DefaultConnectionGene(key=(-20, 259), weight=-1.4195082784119188, enabled=True)
# 	DefaultConnectionGene(key=(-20, 262), weight=-0.3727419803990584, enabled=True)
# 	DefaultConnectionGene(key=(-19, 0), weight=-0.7510589378686603, enabled=True)
# 	DefaultConnectionGene(key=(-19, 1), weight=-0.7806315160911566, enabled=True)
# 	DefaultConnectionGene(key=(-19, 3), weight=-0.9342581100461778, enabled=True)
# 	DefaultConnectionGene(key=(-19, 4), weight=1.1422217553250258, enabled=False)
# 	DefaultConnectionGene(key=(-19, 8), weight=1.5417662079187884, enabled=True)
# 	DefaultConnectionGene(key=(-19, 9), weight=-0.007040382768633391, enabled=True)
# 	DefaultConnectionGene(key=(-19, 10), weight=0.0714361549285662, enabled=True)
# 	DefaultConnectionGene(key=(-19, 11), weight=-1.5584029811092655, enabled=True)
# 	DefaultConnectionGene(key=(-19, 13), weight=0.5245119216988381, enabled=True)
# 	DefaultConnectionGene(key=(-19, 258), weight=0.9052281563346759, enabled=True)
# 	DefaultConnectionGene(key=(-19, 259), weight=-1.639075040486039, enabled=True)
# 	DefaultConnectionGene(key=(-19, 262), weight=-0.9880251744207069, enabled=True)
# 	DefaultConnectionGene(key=(-18, 0), weight=2.158757107817835, enabled=True)
# 	DefaultConnectionGene(key=(-18, 1), weight=-1.7286266125803254, enabled=True)
# 	DefaultConnectionGene(key=(-18, 3), weight=1.4928434186691522, enabled=True)
# 	DefaultConnectionGene(key=(-18, 4), weight=2.232711499143065, enabled=True)
# 	DefaultConnectionGene(key=(-18, 5), weight=0.4675672668734083, enabled=True)
# 	DefaultConnectionGene(key=(-18, 10), weight=2.4422328865038248, enabled=True)
# 	DefaultConnectionGene(key=(-18, 11), weight=-1.1702956524422177, enabled=True)
# 	DefaultConnectionGene(key=(-18, 12), weight=-0.7973331584065028, enabled=True)
# 	DefaultConnectionGene(key=(-18, 256), weight=-1.3487038948682213, enabled=True)
# 	DefaultConnectionGene(key=(-17, 2), weight=-0.18458491617957062, enabled=True)
# 	DefaultConnectionGene(key=(-17, 3), weight=0.9878706551296966, enabled=True)
# 	DefaultConnectionGene(key=(-17, 7), weight=0.9380764612897488, enabled=True)
# 	DefaultConnectionGene(key=(-17, 8), weight=1.6103518808683805, enabled=True)
# 	DefaultConnectionGene(key=(-17, 256), weight=-2.8474660440566577, enabled=True)
# 	DefaultConnectionGene(key=(-17, 259), weight=0.575644548667387, enabled=True)
# 	DefaultConnectionGene(key=(-17, 261), weight=1.813008536601901, enabled=True)
# 	DefaultConnectionGene(key=(-16, 2), weight=0.21330860346453603, enabled=True)
# 	DefaultConnectionGene(key=(-16, 3), weight=1.4833444151915607, enabled=True)
# 	DefaultConnectionGene(key=(-16, 5), weight=0.9541152691802377, enabled=True)
# 	DefaultConnectionGene(key=(-16, 6), weight=0.3569649178834861, enabled=True)
# 	DefaultConnectionGene(key=(-16, 8), weight=0.9112941214945667, enabled=True)
# 	DefaultConnectionGene(key=(-16, 9), weight=1.465147655519794, enabled=True)
# 	DefaultConnectionGene(key=(-16, 13), weight=-0.8790258480374161, enabled=True)
# 	DefaultConnectionGene(key=(-16, 14), weight=0.27872921176298715, enabled=True)
# 	DefaultConnectionGene(key=(-16, 255), weight=0.5541587483430562, enabled=True)
# 	DefaultConnectionGene(key=(-16, 256), weight=1.2420250484139386, enabled=False)
# 	DefaultConnectionGene(key=(-16, 261), weight=0.08044554046086602, enabled=True)
# 	DefaultConnectionGene(key=(-16, 262), weight=1.5500662284669027, enabled=True)
# 	DefaultConnectionGene(key=(-15, 1), weight=0.8696400219655726, enabled=True)
# 	DefaultConnectionGene(key=(-15, 2), weight=-1.3288012357361347, enabled=True)
# 	DefaultConnectionGene(key=(-15, 5), weight=0.43354308559514315, enabled=True)
# 	DefaultConnectionGene(key=(-15, 7), weight=-2.528919855301906, enabled=True)
# 	DefaultConnectionGene(key=(-15, 8), weight=-2.082644276706846, enabled=True)
# 	DefaultConnectionGene(key=(-15, 10), weight=-0.3512419686089936, enabled=True)
# 	DefaultConnectionGene(key=(-15, 14), weight=-1.70558810006847, enabled=True)
# 	DefaultConnectionGene(key=(-15, 255), weight=-2.005697670791685, enabled=True)
# 	DefaultConnectionGene(key=(-15, 256), weight=0.43186540484283603, enabled=False)
# 	DefaultConnectionGene(key=(-15, 261), weight=-0.8292558603880926, enabled=True)
# 	DefaultConnectionGene(key=(-14, 0), weight=1.2211753445852178, enabled=True)
# 	DefaultConnectionGene(key=(-14, 1), weight=0.7554960727964891, enabled=True)
# 	DefaultConnectionGene(key=(-14, 2), weight=-3.0211856558549797, enabled=True)
# 	DefaultConnectionGene(key=(-14, 3), weight=0.7601841605996064, enabled=True)
# 	DefaultConnectionGene(key=(-14, 8), weight=-1.5909066386434487, enabled=True)
# 	DefaultConnectionGene(key=(-14, 10), weight=-0.2437239445898868, enabled=True)
# 	DefaultConnectionGene(key=(-14, 11), weight=-2.711568201111651, enabled=True)
# 	DefaultConnectionGene(key=(-14, 12), weight=0.6008623542409097, enabled=True)
# 	DefaultConnectionGene(key=(-14, 255), weight=1.1015117194778805, enabled=True)
# 	DefaultConnectionGene(key=(-14, 256), weight=-1.0361319649545055, enabled=True)
# 	DefaultConnectionGene(key=(-14, 261), weight=1.2187330832023684, enabled=True)
# 	DefaultConnectionGene(key=(-14, 262), weight=-2.1600704386227454, enabled=True)
# 	DefaultConnectionGene(key=(-13, 0), weight=-0.8123140165241578, enabled=True)
# 	DefaultConnectionGene(key=(-13, 1), weight=-2.872666215602883, enabled=True)
# 	DefaultConnectionGene(key=(-13, 2), weight=0.4472347381454101, enabled=True)
# 	DefaultConnectionGene(key=(-13, 4), weight=-1.9694725078777449, enabled=True)
# 	DefaultConnectionGene(key=(-13, 8), weight=-2.773998863066633, enabled=True)
# 	DefaultConnectionGene(key=(-13, 13), weight=1.0435265928001238, enabled=True)
# 	DefaultConnectionGene(key=(-13, 255), weight=0.9561948483077178, enabled=True)
# 	DefaultConnectionGene(key=(-13, 258), weight=0.3159012711180681, enabled=True)
# 	DefaultConnectionGene(key=(-13, 259), weight=-0.8371843804538879, enabled=True)
# 	DefaultConnectionGene(key=(-13, 262), weight=-2.7602124147412184, enabled=True)
# 	DefaultConnectionGene(key=(-12, 2), weight=-0.33463315602156884, enabled=True)
# 	DefaultConnectionGene(key=(-12, 6), weight=0.5078121042127783, enabled=True)
# 	DefaultConnectionGene(key=(-12, 7), weight=2.1361511534471798, enabled=True)
# 	DefaultConnectionGene(key=(-12, 9), weight=-0.6279820349928683, enabled=True)
# 	DefaultConnectionGene(key=(-12, 10), weight=-3.7609253493258934, enabled=True)
# 	DefaultConnectionGene(key=(-12, 11), weight=-0.07586583140626835, enabled=True)
# 	DefaultConnectionGene(key=(-12, 12), weight=-0.11701998960771572, enabled=True)
# 	DefaultConnectionGene(key=(-12, 13), weight=1.0504405079860724, enabled=True)
# 	DefaultConnectionGene(key=(-12, 255), weight=0.0836057716116338, enabled=True)
# 	DefaultConnectionGene(key=(-12, 256), weight=1.7717221069306037, enabled=True)
# 	DefaultConnectionGene(key=(-12, 258), weight=1.079595450052911, enabled=True)
# 	DefaultConnectionGene(key=(-12, 261), weight=-0.16560213189253933, enabled=True)
# 	DefaultConnectionGene(key=(-11, 0), weight=4.217061033053339, enabled=True)
# 	DefaultConnectionGene(key=(-11, 2), weight=-0.7254576729395491, enabled=True)
# 	DefaultConnectionGene(key=(-11, 3), weight=0.18961382782539132, enabled=False)
# 	DefaultConnectionGene(key=(-11, 7), weight=0.17402058264553816, enabled=True)
# 	DefaultConnectionGene(key=(-11, 8), weight=-0.5188643361003735, enabled=True)
# 	DefaultConnectionGene(key=(-11, 11), weight=-0.10081087054822302, enabled=True)
# 	DefaultConnectionGene(key=(-11, 12), weight=-0.7348355952903309, enabled=True)
# 	DefaultConnectionGene(key=(-11, 255), weight=0.023689566994694572, enabled=True)
# 	DefaultConnectionGene(key=(-11, 256), weight=1.065363140425001, enabled=True)
# 	DefaultConnectionGene(key=(-11, 258), weight=-1.4807582109097106, enabled=True)
# 	DefaultConnectionGene(key=(-11, 261), weight=-0.6087835961736323, enabled=True)
# 	DefaultConnectionGene(key=(-10, 0), weight=-1.0369544239418755, enabled=True)
# 	DefaultConnectionGene(key=(-10, 1), weight=1.5167954550393592, enabled=False)
# 	DefaultConnectionGene(key=(-10, 2), weight=-2.0464762378156482, enabled=True)
# 	DefaultConnectionGene(key=(-10, 4), weight=1.3598395048309078, enabled=True)
# 	DefaultConnectionGene(key=(-10, 5), weight=-2.211344934257642, enabled=True)
# 	DefaultConnectionGene(key=(-10, 9), weight=1.7324033601904585, enabled=True)
# 	DefaultConnectionGene(key=(-10, 10), weight=0.13377406977560735, enabled=True)
# 	DefaultConnectionGene(key=(-10, 12), weight=-0.09898137546491992, enabled=True)
# 	DefaultConnectionGene(key=(-10, 14), weight=-2.212707306861371, enabled=True)
# 	DefaultConnectionGene(key=(-10, 255), weight=-0.005305316707653551, enabled=True)
# 	DefaultConnectionGene(key=(-10, 256), weight=-2.0372971560572384, enabled=True)
# 	DefaultConnectionGene(key=(-10, 259), weight=0.6319664828757208, enabled=True)
# 	DefaultConnectionGene(key=(-9, 1), weight=-3.128731555773521, enabled=True)
# 	DefaultConnectionGene(key=(-9, 4), weight=-0.32280528257053415, enabled=True)
# 	DefaultConnectionGene(key=(-9, 6), weight=-1.4412689720388514, enabled=True)
# 	DefaultConnectionGene(key=(-9, 8), weight=3.162300573414296, enabled=True)
# 	DefaultConnectionGene(key=(-9, 10), weight=0.20567429999795878, enabled=True)
# 	DefaultConnectionGene(key=(-9, 11), weight=-0.12101362283613337, enabled=True)
# 	DefaultConnectionGene(key=(-9, 12), weight=0.038416077135939114, enabled=True)
# 	DefaultConnectionGene(key=(-9, 13), weight=0.4892211103888521, enabled=True)
# 	DefaultConnectionGene(key=(-9, 14), weight=-1.8943406023859386, enabled=True)
# 	DefaultConnectionGene(key=(-9, 255), weight=0.6452004937383397, enabled=True)
# 	DefaultConnectionGene(key=(-9, 256), weight=1.0010701225407428, enabled=True)
# 	DefaultConnectionGene(key=(-9, 258), weight=-1.700557807006423, enabled=True)
# 	DefaultConnectionGene(key=(-9, 259), weight=-0.47547129367118646, enabled=True)
# 	DefaultConnectionGene(key=(-9, 261), weight=1.9275232898886654, enabled=True)
# 	DefaultConnectionGene(key=(-8, 0), weight=1.6475086030601307, enabled=True)
# 	DefaultConnectionGene(key=(-8, 1), weight=-1.282325671003907, enabled=True)
# 	DefaultConnectionGene(key=(-8, 4), weight=-0.657555488225491, enabled=False)
# 	DefaultConnectionGene(key=(-8, 9), weight=1.5372815523123924, enabled=True)
# 	DefaultConnectionGene(key=(-8, 13), weight=3.639922193831365, enabled=True)
# 	DefaultConnectionGene(key=(-7, 0), weight=0.4551148116118172, enabled=True)
# 	DefaultConnectionGene(key=(-7, 3), weight=-0.6317530322159373, enabled=True)
# 	DefaultConnectionGene(key=(-7, 4), weight=3.233377750309777, enabled=True)
# 	DefaultConnectionGene(key=(-7, 5), weight=-0.6446493812081677, enabled=False)
# 	DefaultConnectionGene(key=(-7, 6), weight=1.060388956648981, enabled=True)
# 	DefaultConnectionGene(key=(-7, 9), weight=1.1092667975643848, enabled=True)
# 	DefaultConnectionGene(key=(-7, 11), weight=0.29068614734844955, enabled=True)
# 	DefaultConnectionGene(key=(-7, 12), weight=-2.2073786017453547, enabled=True)
# 	DefaultConnectionGene(key=(-7, 13), weight=1.4565201650304904, enabled=True)
# 	DefaultConnectionGene(key=(-7, 255), weight=-2.277680415541347, enabled=True)
# 	DefaultConnectionGene(key=(-7, 256), weight=-1.2850611307388513, enabled=True)
# 	DefaultConnectionGene(key=(-7, 258), weight=1.8003016131950718, enabled=True)
# 	DefaultConnectionGene(key=(-7, 262), weight=1.2072082157830726, enabled=True)
# 	DefaultConnectionGene(key=(-6, 0), weight=1.1554885369876458, enabled=True)
# 	DefaultConnectionGene(key=(-6, 2), weight=-0.0071635068699930984, enabled=True)
# 	DefaultConnectionGene(key=(-6, 9), weight=0.5963812213313169, enabled=True)
# 	DefaultConnectionGene(key=(-6, 10), weight=1.6743786271021488, enabled=True)
# 	DefaultConnectionGene(key=(-6, 13), weight=-2.402335017511128, enabled=True)
# 	DefaultConnectionGene(key=(-6, 258), weight=1.0968144454621065, enabled=True)
# 	DefaultConnectionGene(key=(-6, 261), weight=0.08457850956610002, enabled=True)
# 	DefaultConnectionGene(key=(-5, 2), weight=-1.794094424639847, enabled=True)
# 	DefaultConnectionGene(key=(-5, 7), weight=-3.9206319312917652, enabled=True)
# 	DefaultConnectionGene(key=(-5, 8), weight=-0.8911448954302413, enabled=True)
# 	DefaultConnectionGene(key=(-5, 9), weight=-0.0665395565844053, enabled=True)
# 	DefaultConnectionGene(key=(-5, 10), weight=-0.48759861392109727, enabled=True)
# 	DefaultConnectionGene(key=(-5, 12), weight=0.2975616711042928, enabled=True)
# 	DefaultConnectionGene(key=(-5, 255), weight=-1.4849780770067502, enabled=True)
# 	DefaultConnectionGene(key=(-5, 262), weight=-2.5972963708308034, enabled=True)
# 	DefaultConnectionGene(key=(-4, 1), weight=0.7493000698863778, enabled=True)
# 	DefaultConnectionGene(key=(-4, 2), weight=0.11364605070800082, enabled=True)
# 	DefaultConnectionGene(key=(-4, 4), weight=0.21353295070584283, enabled=True)
# 	DefaultConnectionGene(key=(-4, 8), weight=-1.9685079484811598, enabled=True)
# 	DefaultConnectionGene(key=(-4, 12), weight=-1.0092630635236102, enabled=False)
# 	DefaultConnectionGene(key=(-4, 14), weight=0.860417544223501, enabled=True)
# 	DefaultConnectionGene(key=(-4, 256), weight=0.9853612179306742, enabled=True)
# 	DefaultConnectionGene(key=(-4, 261), weight=-0.32558050917834724, enabled=True)
# 	DefaultConnectionGene(key=(-3, 1), weight=-1.0115569628048895, enabled=True)
# 	DefaultConnectionGene(key=(-3, 3), weight=-0.7795711075170424, enabled=True)
# 	DefaultConnectionGene(key=(-3, 6), weight=-1.8467508479177248, enabled=False)
# 	DefaultConnectionGene(key=(-3, 7), weight=-0.4767965533297567, enabled=True)
# 	DefaultConnectionGene(key=(-3, 9), weight=0.6337780669202822, enabled=True)
# 	DefaultConnectionGene(key=(-3, 256), weight=-1.3926085695259178, enabled=True)
# 	DefaultConnectionGene(key=(-3, 258), weight=-2.2384936913483044, enabled=True)
# 	DefaultConnectionGene(key=(-3, 259), weight=-0.5827771953743701, enabled=True)
# 	DefaultConnectionGene(key=(-3, 261), weight=-0.0025545588862808805, enabled=False)
# 	DefaultConnectionGene(key=(-2, 0), weight=1.182175160195998, enabled=True)
# 	DefaultConnectionGene(key=(-2, 1), weight=0.11028563246593337, enabled=True)
# 	DefaultConnectionGene(key=(-2, 3), weight=0.1014500019010961, enabled=True)
# 	DefaultConnectionGene(key=(-2, 5), weight=-2.028749104800341, enabled=True)
# 	DefaultConnectionGene(key=(-2, 7), weight=-1.124046401954225, enabled=True)
# 	DefaultConnectionGene(key=(-2, 9), weight=-1.3069204458822097, enabled=False)
# 	DefaultConnectionGene(key=(-2, 10), weight=-0.2987786205243787, enabled=True)
# 	DefaultConnectionGene(key=(-2, 11), weight=1.1575377922613554, enabled=True)
# 	DefaultConnectionGene(key=(-2, 12), weight=1.6580826725951896, enabled=True)
# 	DefaultConnectionGene(key=(-2, 14), weight=-0.6805030284461953, enabled=True)
# 	DefaultConnectionGene(key=(-2, 256), weight=-0.999668957678539, enabled=True)
# 	DefaultConnectionGene(key=(-2, 258), weight=1.8936711964866693, enabled=False)
# 	DefaultConnectionGene(key=(-2, 259), weight=1.4632405718798909, enabled=False)
# 	DefaultConnectionGene(key=(-2, 262), weight=-0.8401880334937184, enabled=True)
# 	DefaultConnectionGene(key=(-1, 2), weight=0.6178259874340088, enabled=True)
# 	DefaultConnectionGene(key=(-1, 4), weight=-1.7278773398648926, enabled=True)
# 	DefaultConnectionGene(key=(-1, 6), weight=2.049605552795579, enabled=True)
# 	DefaultConnectionGene(key=(-1, 10), weight=3.069409446780843, enabled=True)
# 	DefaultConnectionGene(key=(-1, 11), weight=0.007006610137636729, enabled=True)
# 	DefaultConnectionGene(key=(-1, 12), weight=-0.07015464574049438, enabled=True)
# 	DefaultConnectionGene(key=(-1, 13), weight=0.8182700244483988, enabled=True)
# 	DefaultConnectionGene(key=(-1, 255), weight=0.1640012378666758, enabled=True)
# 	DefaultConnectionGene(key=(-1, 258), weight=0.5096596298052982, enabled=True)
# 	DefaultConnectionGene(key=(-1, 262), weight=-2.5578642262834816, enabled=True)
# 	DefaultConnectionGene(key=(255, 2), weight=2.0559608130428653, enabled=True)
# 	DefaultConnectionGene(key=(255, 3), weight=1.571379938501158, enabled=True)
# 	DefaultConnectionGene(key=(255, 4), weight=-0.37097912703379604, enabled=False)
# 	DefaultConnectionGene(key=(255, 5), weight=-1.9655437165819427, enabled=True)
# 	DefaultConnectionGene(key=(255, 7), weight=1.1160000780599182, enabled=True)
# 	DefaultConnectionGene(key=(255, 8), weight=-0.0016753438731789139, enabled=True)
# 	DefaultConnectionGene(key=(255, 11), weight=-3.986658465706051, enabled=True)
# 	DefaultConnectionGene(key=(255, 13), weight=-3.2395914405083044, enabled=True)
# 	DefaultConnectionGene(key=(256, 2), weight=0.5845972611712588, enabled=True)
# 	DefaultConnectionGene(key=(256, 4), weight=0.5214087470061484, enabled=True)
# 	DefaultConnectionGene(key=(256, 6), weight=1.7326084054580726, enabled=True)
# 	DefaultConnectionGene(key=(256, 9), weight=-0.5116031180163256, enabled=True)
# 	DefaultConnectionGene(key=(256, 11), weight=-1.2939332052458874, enabled=True)
# 	DefaultConnectionGene(key=(256, 14), weight=-0.03512163719799566, enabled=True)
# 	DefaultConnectionGene(key=(258, 0), weight=-0.03652574747607695, enabled=True)
# 	DefaultConnectionGene(key=(258, 1), weight=3.5700175478182197, enabled=True)
# 	DefaultConnectionGene(key=(258, 3), weight=2.689458791136038, enabled=True)
# 	DefaultConnectionGene(key=(258, 6), weight=1.1799762489426067, enabled=True)
# 	DefaultConnectionGene(key=(258, 8), weight=0.8058213495831579, enabled=True)
# 	DefaultConnectionGene(key=(258, 11), weight=0.2690003423054981, enabled=True)
# 	DefaultConnectionGene(key=(259, 1), weight=0.19501631645861453, enabled=True)
# 	DefaultConnectionGene(key=(259, 2), weight=-0.5282875385496288, enabled=True)
# 	DefaultConnectionGene(key=(259, 5), weight=-0.543521629599713, enabled=True)
# 	DefaultConnectionGene(key=(259, 6), weight=0.7618110741823235, enabled=True)
# 	DefaultConnectionGene(key=(259, 7), weight=-0.20993976007502826, enabled=True)
# 	DefaultConnectionGene(key=(259, 8), weight=0.42273568793205163, enabled=True)
# 	DefaultConnectionGene(key=(259, 10), weight=-0.5773855195004451, enabled=True)
# 	DefaultConnectionGene(key=(259, 12), weight=1.3404169418055765, enabled=True)
# 	DefaultConnectionGene(key=(259, 13), weight=-1.3292184013784338, enabled=True)
# 	DefaultConnectionGene(key=(259, 14), weight=-1.4391424128711723, enabled=True)
# 	DefaultConnectionGene(key=(261, 0), weight=1.3796130342551263, enabled=True)
# 	DefaultConnectionGene(key=(261, 1), weight=1.1313174116742373, enabled=True)
# 	DefaultConnectionGene(key=(261, 2), weight=-0.8577746094029328, enabled=True)
# 	DefaultConnectionGene(key=(261, 4), weight=1.0251486831816319, enabled=True)
# 	DefaultConnectionGene(key=(261, 6), weight=-0.5098197723430159, enabled=True)
# 	DefaultConnectionGene(key=(261, 7), weight=1.124535921269721, enabled=True)
# 	DefaultConnectionGene(key=(261, 8), weight=-2.197779425899209, enabled=True)
# 	DefaultConnectionGene(key=(261, 14), weight=1.379308871508013, enabled=True)
# 	DefaultConnectionGene(key=(262, 2), weight=0.18228675895629365, enabled=True)
# 	DefaultConnectionGene(key=(262, 6), weight=-1.6006800309318772, enabled=True)
# 	DefaultConnectionGene(key=(262, 7), weight=-3.9189781477722114, enabled=True)
# 	DefaultConnectionGene(key=(262, 8), weight=2.6837132895078732, enabled=True)
# 	DefaultConnectionGene(key=(262, 12), weight=3.0430104390640516, enabled=False)
# 	DefaultConnectionGene(key=(262, 14), weight=0.3867132555413739, enabled=True)
# 	DefaultConnectionGene(key=(469, 9), weight=-1.7125314482356897, enabled=True)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-78-7ee686cb7978> in <module>()
#      18 done = False
#      19 while not done:
# ---> 20       action = net.activate(observation)
#      21       for i in range(len(action)):
#      22         action[i] = (action[i] + 1)/2.0
#
# /usr/local/lib/python3.7/dist-packages/neat/nn/feed_forward.py in activate(self, inputs)
#      12     def activate(self, inputs):
#      13         if len(self.input_nodes) != len(inputs):
# ---> 14             raise RuntimeError("Expected {0:n} inputs, got {1:n}".format(len(self.input_nodes), len(inputs)))
#      15
#      16         for k, v in zip(self.input_nodes, inputs):
#
# RuntimeError: Expected 784 inputs, got 27
